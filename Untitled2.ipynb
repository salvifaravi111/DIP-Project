# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
#img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,100,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
blur = cv2.bilateralFilter(img,9,75,75)
plt.imshow(blur,'gray')
plt.show()

# %%
ret,th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.imshow(th_blur,'gray')
plt.show()

# %%
ret,th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.subplot(2,2,1),plt.imshow(img,'gray')
plt.subplot(2,2,2),plt.imshow(th_blur,'gray')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10,6)
ret,th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.subplot(2,2,1),plt.imshow(img,'gray')
plt.subplot(2,2,2),plt.imshow(th_blur,'gray')
plt.show()

# %%
# global thresholding
ret1,th1 = cv.threshold(img,100,255,cv.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv.threshold(img,100,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
ret3,th3 = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
#replicate = cv2.copyMakeBorder(img,10,10,10,10,cv2.BORDER_REPLICATE)
blur = cv2.bilateralFilter(img,9,60,60)
ret,th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.subplot(2,2,1),plt.imshow(img,'gray')
plt.subplot(2,2,2),plt.imshow(blur,'gray')
plt.subplot(2,2,3),plt.imshow(th_blur,'gray')
plt.show()

# %%
th_blur = cv.threshold(cv2.bilateralFilter(img,9,60,60),100,255,cv.THRESH_BINARY)
plt.imshow(th_blur,'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-abf980875db0> in <module>
#       1 th_blur = cv.threshold(cv2.bilateralFilter(img,9,60,60),100,255,cv.THRESH_BINARY)
# ----> 2 plt.imshow(th_blur,'gray')
#       3 plt.show()
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
blur = cv2.bilateralFilter(img,9,60,60)
th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.imshow(th_blur,'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-0fc6f5e45071> in <module>
#       2 blur = cv2.bilateralFilter(img,9,60,60)
#       3 th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
# ----> 4 plt.imshow(th_blur,'gray')
#       5 plt.show()
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
#replicate = cv2.copyMakeBorder(img,10,10,10,10,cv2.BORDER_REPLICATE)
blur = cv2.bilateralFilter(img,9,60,60)
ret,th_blur = cv.threshold(blur,100,255,cv.THRESH_BINARY)
plt.subplot(2,2,1),plt.imshow(img,'gray')
plt.subplot(2,2,2),plt.imshow(blur,'gray')
plt.subplot(2,2,3),plt.imshow(th_blur,'gray')
plt.show()

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,6,0,6,cv2.BORDER_REPLICATE)
ret,th_blur = cv.threshold(cv2.bilateralFilter(img,9,60,60),100,255,cv.THRESH_BINARY)
plt.imshow(th_blur,'gray')
plt.show()

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,0,0,1,cv2.BORDER_REPLICATE)
height = np.size(replicate, 0)
width = np.size(replicate, 1)
print(height,width)
# Out:
# 103 97

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,1,0,0,cv2.BORDER_REPLICATE)
height = np.size(replicate, 0)
width = np.size(replicate, 1)
print(height,width)
# Out:
# 104 96

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,1,0,0,cv2.BORDER_REPLICATE)
box1 = replicate[0:26,0:24]
box2 = replicate[26:52,24:48]
box3 = replicate[52:78,48:72]
box4 = replicate[78:104,72:96]
plt.subplot(2,2,1),plt.imshow(box1,'gray')
plt.subplot(2,2,2),plt.imshow(box2,'gray')
plt.subplot(2,2,3),plt.imshow(box3,'gray')
plt.subplot(2,2,4),plt.imshow(box4,'gray')
plt.show()

# %%
img = cv.imread('Real//50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,1,0,0,cv2.BORDER_REPLICATE)
box1 = replicate[0:26,0:24]
box2 = replicate[26:52,24:48]
box3 = replicate[52:78,48:72]
box4 = replicate[78:104,72:96]
boxes = [box1,box2,box3,box4]
plt.subplot(2,2,1),plt.imshow(boxes[0],'gray')
plt.subplot(2,2,2),plt.imshow(box2,'gray')
plt.subplot(2,2,3),plt.imshow(box3,'gray')
plt.subplot(2,2,4),plt.imshow(box4,'gray')
plt.show()

# %%
img = cv2.imread('50__M_Right_index_finger.BMP',0)
replicate = cv2.copyMakeBorder(img,0,1,0,0,cv2.BORDER_REPLICATE)
ret,img2 = cv2.threshold(cv2.bilateralFilter(replicate,9,60,60),100,255,cv2.THRESH_BINARY)
temp = cv2.imread('50__M_Right_index_finger_copy.BMP',0)
replicate = cv2.copyMakeBorder(temp,0,1,0,0,cv2.BORDER_REPLICATE)
ret2,template = cv2.threshold(cv2.bilateralFilter(replicate,9,60,60),100,255,cv2.THRESH_BINARY)

box1 = img2[0:26,0:24]
box2 = img2[26:52,24:48]
box3 = img2[52:78,48:72]
box4 = img2[78:104,72:96]
boxes = [box1,box2,box3,box4]

box1 = template[0:26,0:24]
box2 = template[26:52,24:48]
box3 = template[52:78,48:72]
box4 = template[78:104,72:96]
tboxes = [box1,box2,box3,box4]

w, h = box1.shape[::-1]

# All the 6 methods for comparison in a list
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for i in range(0,4):
    for meth in methods:
        img = boxes[i].copy()
        method = eval(meth)

        # Apply template Matching
        res = cv2.matchTemplate(img,tboxes[i],method)
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

        # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
        if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
            top_left = min_loc
        else:
            top_left = max_loc
        bottom_right = (top_left[0] + w, top_left[1] + h)

        cv2.rectangle(img,top_left, bottom_right, 255, 2)

        plt.subplot(121),plt.imshow(res,cmap = 'gray')
        plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
        plt.subplot(122),plt.imshow(img,cmap = 'gray')
        plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
        plt.suptitle(meth)

        plt.show()
